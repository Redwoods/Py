# %% [markdown]
# # Custom dataset
# - 미니 배치
# - 데이터 로드

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
torch.__version__
# Out:
# '1.9.1+cu111'

# %%
from torch.utils.data import TensorDataset # 텐서데이터셋
from torch.utils.data import DataLoader # 데이터로더
from torch.utils.data import Dataset

# %%
# 랜덤 시드(random seed)를 줍니다.
torch.manual_seed(1)

# %%
# 데이터
x_train  =  [[73,  80,  75], 
            [93,  88,  93], 
            [89,  91,  90], 
            [96,  98,  100],   
            [73,  66,  70]]
y_train  =  [[152],  [185],  [180],  [196],  [142]]
# x_train  =  torch.FloatTensor([[73,  80,  75], 
#                                [93,  88,  93], 
#                                [89,  91,  90], 
#                                [96,  98,  100],   
#                                [73,  66,  70]])  
# y_train  =  torch.FloatTensor([[152],  [185],  [180],  [196],  [142]])

# %%
# Dataset 상속
class CustomDataset(Dataset): 
  def __init__(self, x, y):
    self.x_data = x
    self.y_data = y

  # 총 데이터의 개수를 리턴
  def __len__(self): 
    return len(self.x_data)

  # 인덱스를 입력받아 그에 맵핑되는 입출력 데이터를 파이토치의 Tensor 형태로 리턴
  def __getitem__(self, idx): 
    x = torch.FloatTensor(self.x_data[idx])
    y = torch.FloatTensor(self.y_data[idx])
    return x, y

# %% [markdown]
# ### custom dataset -> dataloader
# - 데이터셋을 만들었다면 데이터로더를 사용 가능합니다.
#
# - 데이터로더는 기본적으로 2개의 인자를 입력받는다.
#     - 하나는 데이터셋
#     - 미니 배치의 크기입니다.
#
# - 미니 배치의 크기는 통상적으로 2의 배수를 사용합니다.

# %%
dataset = CustomDataset(x_train, y_train)
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
dataset

# %%
class MultivariateLinearRegressionModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear = nn.Linear(3, 1) # 다중 선형 회귀이므로 input_dim=3, output_dim=1.

    def forward(self, x):
        return self.linear(x)

# %%
model = MultivariateLinearRegressionModel()
print(list(model.parameters()))  # Initial random parameters
# Out:
# [Parameter containing:
# tensor([[-0.5435,  0.3462, -0.1188]], requires_grad=True), Parameter containing:
# tensor([0.2937], requires_grad=True)]

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
# Learning using mini-batch from dataloader
nb_epochs = 20
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    print(batch_idx)
    print(samples)
    x_train, y_train = samples
    # H(x) 계산
    prediction = model(x_train)

    # cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch    0/20 Batch 1/3 Cost: 40394.078125
# 1
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch    0/20 Batch 2/3 Cost: 10625.849609
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    0/20 Batch 3/3 Cost: 5451.569824
# 0
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch    1/20 Batch 1/3 Cost: 937.502686
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch    1/20 Batch 2/3 Cost: 265.944763
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    1/20 Batch 3/3 Cost: 244.422516
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch    2/20 Batch 1/3 Cost: 3.523164
# 1
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch    2/20 Batch 2/3 Cost: 55.838959
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    2/20 Batch 3/3 Cost: 2.371156
# 0
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch    3/20 Batch 1/3 Cost: 21.615038
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch    3/20 Batch 2/3 Cost: 1.536141
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    3/20 Batch 3/3 Cost: 23.620941
# 0
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch    4/20 Batch 1/3 Cost: 12.848389
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch    4/20 Batch 2/3 Cost: 17.578531
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    4/20 Batch 3/3 Cost: 18.382185
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 89.,  91.,  90.]]), tensor([[196.],
#         [180.]])]
# Epoch    5/20 Batch 1/3 Cost: 11.401794
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch    5/20 Batch 2/3 Cost: 20.960949
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch    5/20 Batch 3/3 Cost: 28.939528
# 0
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch    6/20 Batch 1/3 Cost: 14.807865
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch    6/20 Batch 2/3 Cost: 2.599264
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch    6/20 Batch 3/3 Cost: 33.501408
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch    7/20 Batch 1/3 Cost: 16.869854
# 1
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch    7/20 Batch 2/3 Cost: 24.528923
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    7/20 Batch 3/3 Cost: 10.461182
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch    8/20 Batch 1/3 Cost: 8.686996
# 1
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch    8/20 Batch 2/3 Cost: 30.927486
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch    8/20 Batch 3/3 Cost: 7.897373
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch    9/20 Batch 1/3 Cost: 7.612912
# 1
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  66.,  70.]]), tensor([[196.],
#         [142.]])]
# Epoch    9/20 Batch 2/3 Cost: 18.703394
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch    9/20 Batch 3/3 Cost: 16.064274
# 0
# [tensor([[89., 91., 90.],
#         [73., 66., 70.]]), tensor([[180.],
#         [142.]])]
# Epoch   10/20 Batch 1/3 Cost: 12.797729
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   10/20 Batch 2/3 Cost: 8.214132
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   10/20 Batch 3/3 Cost: 23.461618
# 0
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   11/20 Batch 1/3 Cost: 16.458553
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   11/20 Batch 2/3 Cost: 8.302062
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   11/20 Batch 3/3 Cost: 18.300760
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 73.,  80.,  75.]]), tensor([[196.],
#         [152.]])]
# Epoch   12/20 Batch 1/3 Cost: 3.977031
# 1
# [tensor([[89., 91., 90.],
#         [93., 88., 93.]]), tensor([[180.],
#         [185.]])]
# Epoch   12/20 Batch 2/3 Cost: 16.020334
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   12/20 Batch 3/3 Cost: 29.221930
# 0
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   13/20 Batch 1/3 Cost: 13.251047
# 1
# [tensor([[73., 80., 75.],
#         [93., 88., 93.]]), tensor([[152.],
#         [185.]])]
# Epoch   13/20 Batch 2/3 Cost: 15.146645
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   13/20 Batch 3/3 Cost: 6.902967
# 0
# [tensor([[73., 80., 75.],
#         [73., 66., 70.]]), tensor([[152.],
#         [142.]])]
# Epoch   14/20 Batch 1/3 Cost: 20.339725
# 1
# [tensor([[ 93.,  88.,  93.],
#         [ 96.,  98., 100.]]), tensor([[185.],
#         [196.]])]
# Epoch   14/20 Batch 2/3 Cost: 8.538606
# 2
# [tensor([[89., 91., 90.]]), tensor([[180.]])]
# Epoch   14/20 Batch 3/3 Cost: 4.507004
# 0
# [tensor([[ 96.,  98., 100.],
#         [ 93.,  88.,  93.]]), tensor([[196.],
#         [185.]])]
# Epoch   15/20 Batch 1/3 Cost: 9.943769
# 1
# [tensor([[73., 66., 70.],
#         [89., 91., 90.]]), tensor([[142.],
#         [180.]])]
# Epoch   15/20 Batch 2/3 Cost: 13.766291
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   15/20 Batch 3/3 Cost: 19.031166
# 0
# [tensor([[93., 88., 93.],
#         [73., 66., 70.]]), tensor([[185.],
#         [142.]])]
# Epoch   16/20 Batch 1/3 Cost: 29.411785
# 1
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   16/20 Batch 2/3 Cost: 15.633769
# 2
# [tensor([[ 96.,  98., 100.]]), tensor([[196.]])]
# Epoch   16/20 Batch 3/3 Cost: 1.366826
# 0
# [tensor([[73., 66., 70.],
#         [93., 88., 93.]]), tensor([[142.],
#         [185.]])]
# Epoch   17/20 Batch 1/3 Cost: 29.227505
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   17/20 Batch 2/3 Cost: 8.651358
# 2
# [tensor([[73., 80., 75.]]), tensor([[152.]])]
# Epoch   17/20 Batch 3/3 Cost: 12.546249
# 0
# [tensor([[89., 91., 90.],
#         [73., 80., 75.]]), tensor([[180.],
#         [152.]])]
# Epoch   18/20 Batch 1/3 Cost: 2.676948
# 1
# [tensor([[ 73.,  66.,  70.],
#         [ 96.,  98., 100.]]), tensor([[142.],
#         [196.]])]
# Epoch   18/20 Batch 2/3 Cost: 23.020639
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   18/20 Batch 3/3 Cost: 20.121801
# 0
# [tensor([[ 73.,  80.,  75.],
#         [ 96.,  98., 100.]]), tensor([[152.],
#         [196.]])]
# Epoch   19/20 Batch 1/3 Cost: 18.024099
# 1
# [tensor([[93., 88., 93.],
#         [89., 91., 90.]]), tensor([[185.],
#         [180.]])]
# Epoch   19/20 Batch 2/3 Cost: 9.444228
# 2
# [tensor([[73., 66., 70.]]), tensor([[142.]])]
# Epoch   19/20 Batch 3/3 Cost: 23.168087
# 0
# [tensor([[73., 66., 70.],
#         [73., 80., 75.]]), tensor([[142.],
#         [152.]])]
# Epoch   20/20 Batch 1/3 Cost: 21.232851
# 1
# [tensor([[ 89.,  91.,  90.],
#         [ 96.,  98., 100.]]), tensor([[180.],
#         [196.]])]
# Epoch   20/20 Batch 2/3 Cost: 11.280905
# 2
# [tensor([[93., 88., 93.]]), tensor([[185.]])]
# Epoch   20/20 Batch 3/3 Cost: 14.621032

# %%
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]]) 
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var) 
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[157.2804]], grad_fn=<AddmmBackward>)

# %%
print(list(model.parameters()))
# Out:
# [Parameter containing:
# tensor([[0.2419, 1.1128, 0.6705]], requires_grad=True), Parameter containing:
# tensor([0.3028], requires_grad=True)]

# %% [markdown]
# ---
