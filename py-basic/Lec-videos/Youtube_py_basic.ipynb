# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Redwoods/Py/blob/master/py-basic/Lec-videos/Youtube_py_basic.ipynb)

# %% [markdown]
# # Youtube videos for py-basic

# %%
from IPython.lib.display import YouTubeVideo

# %% [markdown]
# ## **Colaboratory** by google

# %%
YouTubeVideo('XRBXMohjQos')

# %% [markdown]
# ## **Jupyter** lab

# %%
YouTubeVideo('70sRgL42c1w')
