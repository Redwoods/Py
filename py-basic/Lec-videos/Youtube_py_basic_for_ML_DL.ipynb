# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Redwoods/Py/blob/master/py-basic/Lec-videos/Youtube_py_basic_for_ML_DL.ipynb)

# %% [markdown]
# # 머신러닝과 딥러닝을 위한 기초 파이썬

# %% [markdown]
# # Youtube videos: python-basic for ML & DL

# %% [markdown]
# >[머신러닝과 딥러닝을 위한 기초 파이썬](#scrollTo=XVfTQUfFGGzV)
#
# >[Youtube videos: python-basic for ML & DL](#scrollTo=r1WOWgN7qSm8)
#
# >>[파이썬 머신러닝 딥러닝 과정소개](#scrollTo=36rLKy-yojpr)
#
# >>[파이썬 데이터타입](#scrollTo=Gjwb97Y2qFOP)
#
# >>[파이썬 조건문 반복문](#scrollTo=4j6sn0VsGqhB)
#
# >>[파이썬 함수 람다](#scrollTo=8_30FR9MGGz8)
#
# >>[파이썬 클래스](#scrollTo=1oogzJTXGG0C)
#
# >>[파이썬 Numpy (I)](#scrollTo=1bdYUX2lGG0H)
#
# >>[파이썬 Numpy (II)](#scrollTo=zuCGePhPGG0L)
#
# >>[파이썬 Numpy (III)](#scrollTo=KjSC9y2BGG0P)

# %%
from IPython.lib.display import YouTubeVideo

# %% [markdown]
# ## 파이썬 **머신러닝 딥러닝 과정소개**

# %%
YouTubeVideo('vcCaSBJpsHk')

# %% [markdown]
# ## 파이썬 **데이터타입**

# %%
YouTubeVideo('etM5NLvp_do')

# %% [markdown]
# ## 파이썬 **조건문 반복문**

# %%
YouTubeVideo('dlE5Ht_Hrwg')

# %% [markdown]
# ## 파이썬 **함수 람다**

# %%
YouTubeVideo('oL6LIuw_p94')

# %% [markdown]
# ## 파이썬 **클래스**

# %%
YouTubeVideo('5Xy5Ju7hYo4')

# %% [markdown]
# ## 파이썬 **Numpy (I)**

# %%
YouTubeVideo('ku9-AxaznSA')

# %% [markdown]
# ## 파이썬 **Numpy (II)**

# %%
YouTubeVideo('dnJ3JESmBkE')

# %% [markdown]
# ## 파이썬 **Numpy (III)**

# %%
YouTubeVideo('8nX9C8EjYkw')
