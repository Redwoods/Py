# %% [markdown]
# <a href="https://colab.research.google.com/github/Redwoods/Py/blob/master/py2020/Notebook/ch5_code04__name__.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## if \_\_name\_\_ == "\_\_main\_\_" 의 의미는?

# %% [markdown]
# ## Filename: run_or_import.py
# ### Save run_or_import.py in /content folder.
# ```
# # run_or_import.py
# if __name__ == '__main__':
# 	print('run *.py')
# else:
# 	print('import module')
# ```

# %% [markdown]
# ### run *.py
# - 다음 조건이 성립.
# > \_\_name\_\_ == '\_\_main\_\_'

# %%
run run_or_import.py
# Out:
# run *.py

# %%
# !python run_or_import.py
# Out:
# run *.py

# %% [markdown]
# ### import module
# - 다음 조건이 성립
# > \_\_name\_\_ != '\_\_main\_\_'

# %%
import run_or_import
# Out:
# import module

# %% [markdown]
# ### 차이점을 잘 이해했나요?
