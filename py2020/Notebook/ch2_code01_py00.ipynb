# %% [markdown]
# <a href="https://colab.research.google.com/github/Redwoods/Py/blob/master/py2020/Notebook/ch2_code01_py00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ch2_code01.ipynb
# ## py00

# %%
# ch2_01_numeric.py
#
print("숫자형: 정수") # 동적타이핑 (Dynamic typing)
a = 123
a = -178
# a = 0
# a
print(a)
# Out:
# 숫자형: 정수
# -178

# %%
a1 = 123
a2 = -178
a3 = 0
print(a1,a2,a3)
a
# Out:
# 123 -178 0
# -178

# %%
print("a1 = ",a1)
# Out:
# a1 =  123

# %% [markdown]
# ### 다음과 같이 출력해 보세요.
# > a1 = 123 a2 = -179 a3 = 0

# %%
print("a1 = ",a1,", a2 = ",a2,", a3 = ",a3)
# Out:
# a1 =  123 , a2 =  -178 , a3 =  0

# %% [markdown]
# ### 숫자형: 실수
# > 파이썬에서 실수를 표현해보자.

# %%
print("숫자형: 실수")
a1 = 1.2
a2 = -3.48
a3 = 4.24e10
a4 = 4.24e-10
a1,a2,a3,a4
# Out:
# 숫자형: 실수
# (1.2, -3.48, 42400000000.0, 4.24e-10)

# %%
print("숫자형: 8진수와 16진수")
a = 0o177
print(a)
a = 0x8FF  # Hexadecimal: 16진수, 0 ~ F
print(a)
a = 0xABC
a
# Out:
# 숫자형: 8진수와 16진수
# 127
# 2303
# 2748

# %% [markdown]
# ### 숫자형: 연산자와 연산

# %%
print("숫자형: 연산자와 연산")
a = 3
b = 4
print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 숫자형: 연산자와 연산
# 7
# -1
# 12
# 0.75

# %%
print(a ** b)
print(a % b)
print(b % a)
a // b
# Out:
# 81
# 3
# 1
# 0

# %%
14 // 3 ,14 % 3
# Out:
# (4, 2)

# %% [markdown]
# ## 문자열 정의와 출력

# %%
# ch2_02_string.py
# "Life is too short, you need python"
# 'Life is too short, you need python'
# """Life is too short, you need python"""
# '''Life is too short, you need python'''

print("문자열: '")
food = "Python's favorite food is perl"
food
# Out:
# 문자열: '
# "Python's favorite food is perl"

# %%
food = 'Python's favorite food is perl'  # Error
# Out:
#   File "<ipython-input-31-f53082fb6fe1>", line 1
#     food = 'Python's favorite food is perl'  # Error
#                    ^
# SyntaxError: invalid syntax

# %%
food = "Python's favorite food is perl"
food
# Out:
# "Python's favorite food is perl"

# %%
say = '"Python is very easy." he says.'
say
# Out:
# '"Python is very easy." he says.'

# %%
print("문자열: \ 이용")
food = 'Python\'s favorite food is perl'
say ="\"Python is very easy.\" he says."
print(food)
print(say)
say
# Out:
# 문자열: \ 이용
# Python's favorite food is perl
# "Python is very easy." he says.
# '"Python is very easy." he says.'

# %% [markdown]
# ### 이스케이프 코드를 사용한 출력

# %%
# 이스케이프 코드
print("문자열: 이스케이프 코드 이용")
multiline = "Life is too short\nYou need python"
# multiline
print(multiline)
# Out:
# 문자열: 이스케이프 코드 이용
# Life is too short
# You need python

# %% [markdown]
# ### 여러줄 문자열 처리
# - """ .... """
# - ''' .... '''

# %%
# 여러줄 문자열 처리
multiline = '''
... Life is too short
... You need python
... '''
multiline2 = """
인생은 짧고,
파이썬은 필요하다.
"""
multiline3 = """인생은 짧고,
파이썬은 필요하다.
"""

print(multiline)
print(multiline2)
print(multiline3)
# Out:
# Life is too short
# You need python
#
#
# 인생은 짧고,
# 파이썬은 필요하다.
#
# 인생은 짧고,
# 파이썬은 필요하다.

# %% [markdown]
# ### 문자열 연산

# %%
################################################
print("문자열 연산: 더하기")
head = "Python"
tail = " is fun!"
head + tail
# Out:
# 문자열 연산: 더하기
# 'Python is fun!'

# %%
print("문자열 연산: 곱하기")
a = "python"
a * 2
# Out:
# 문자열 연산: 곱하기
# 'pythonpython'

# %%
#####################################
# multistring.py
print("=" * 50)
print("I am now coding Python!")
print("*" * 50)
#####################################
# Out:
# ==================================================
# I am now coding Python!
# **************************************************

# %%
# 내장함수: len()
print("문자열 연산: 길이 구하기 - len()")
a = "Life is too short."
len(a)
# Out:
# 문자열 연산: 길이 구하기 - len()
# 18

# %% [markdown]
# ### 문자열 인덱싱, 슬라이싱

# %%
#####################################
#
# 문자열 인덱싱과 슬라이싱
#
#####################################
print("문자열: 인덱싱이란?")
a = "Life is too short, You need Python"
print(a[3])
print(a[15])
print(a[23])
# Out:
# 문자열: 인덱싱이란?
# e
# r
# n

# %%
# "파이썬은 0부터 숫자를 센다."
print("문자열: 인덱싱 활용")

a = "Life is too short, You need Python"
# a[0]  # L

# a[12]  # s

# a[-1]  # n

# # a[-0]
a[-2] # o
# a[-5]
# a[-12]
# Out:
# 문자열: 인덱싱 활용
# 'o'

# %%
#####################################
print("문자열: 슬라이싱이란?")
a = "Life is too short, You need Python"
# Life 를 뽑아낼려면 어떻게?
b = a[0] + a[1] + a[2] + a[3]  # 문자열 뎌하기 연산 "L","i"
b
# Out:
# 문자열: 슬라이싱이란?
# 'Life'

# %%
# slicing (슬라이싱)
a[0:4]  # 0 <= index < 4
# Out:
# 'Life'

# %%
a[0:5]
print(a[5:7])
print(a[12:17])
# Out:
# is
# short

# %%
# : 의 사용
print(a[:4])
print(a[19:])
print(a[:17])
# Out:
# Life
# You need Python
# Life is too short

# %%
a = "Life is too short, You need Python"
a
# Out:
# 'Life is too short, You need Python'

# %%
a[0:4]
a[:4]
a[:]
# Out:
# 'Life is too short, You need Python'

# %%
# a[19:-7] ?
a[19:-7]
# Out:
# 'You need'

# %%
print("문자열: 슬라이싱 응용?")
a = "20190909Sunny"
date = a[:8]
weather = a[8:]
date,weather
# Out:
# 문자열: 슬라이싱 응용?
# ('20190909', 'Sunny')

# %%
a = "20190917Rainy"
year = a[:4]
day = a[4:8]
weather = a[8:]
year,day,weather
# Out:
# ('2019', '0917', 'Rainy')

# %%
# "Pithon"이라는 문자열을 "Python"으로 바꾸려면?
a = "Pithon"
print(a[1])
a[1] = 'y'  # Error (immutable한 자료형)
# Out:
# i
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-d77221cee730> in <module>()
#       1 a = "Pithon"
#       2 print(a[1])
# ----> 3 a[1] = 'y'  # Error (immutable한 자료형)
#
# TypeError: 'str' object does not support item assignment

# %%
#################
a = "Pithon"
print(a[:1])
print(a[2:])
a[:1] + 'y' + a[2:]  # Python
a
a,a[:1],a[2:],a[:1]+'y'+a[2:]
# Out:
# P
# thon
# ('Pithon', 'P', 'thon', 'Python')

# %% [markdown]
# ## 문자열 포매팅과 출력

# %%
# ch2_03_string_formating.py

print("문자열: 포매팅이란?")
# 1. 숫자 바로 대입
"I eat %d apples." % 3
# Out:
# 문자열: 포매팅이란?
# 'I eat 3 apples.'

# %%
# 2. 문자열 바로 대입
"I eat %s apples." % "five"
# Out:
# 'I eat five apples.'

# %%
# 3. 숫자 값을 나타내는 변수로 대입
number = 3
"I eat %d apples." % number
# Out:
# 'I eat 3 apples.'

# %%
# 4. 2개 이상의 값 넣기
number = 10
day = "three"
# "I ate %d apples. so I was sick for %s days." % number, day   # Error
"I ate %d apples. so I was sick for %s days." % (number, day)
# 소괄호 안에 콤마(,)로 구분하여 각각의 값을 넣어 준다.
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %%
print("문자열: 포맷 코드")
# %d, %s, %c, %f, %o, %x, %%
# %s, 묵시적 형변환
# "I have %s apples" % 3
# "rate is %s" % 3.234

# "Error is %d%." % 98
"Error is %d%%." % 98
# Out:
# 문자열: 포맷 코드
# 'Error is 98%.'

# %%
###############################################-p60
print("문자열: 포맷 코드와 숫자 함께 사용하기")
# 1. 정렬과 공백
# "%-5s" % "hi"
"%-4sjane." % "hi"
# Out:
# 문자열: 포맷 코드와 숫자 함께 사용하기
# 'hi  jane.'

# %%
# 2. 소수점 표현하기
# "%0.2f" % 3.42134234
"%10.4f" % 3.42134234
# Out:
# '    3.4213'

# %% [markdown]
# ### format() 함수 이용한 문자열 출력

# %%
print("문자열: format 함수를 사용한 포매팅")
# 1. 숫자 바로 대입하기
# "I eat {0} apples".format(3)
"I eat {1} {0} apples".format(3, 4)
# Out:
# 문자열: format 함수를 사용한 포매팅
# 'I eat 4 3 apples'

# %%
# 2. 문자열 바로 대입하기
# "I eat {0} apples".format("five")
"I eat {0} apples from {1} boxes".format("five", "three")
# Out:
# 'I eat five apples from three boxes'

# %%
# 3. 숫자 값을 가진 변수로 대입하기
number = 3
# "I eat {0} apples".format(number)
"I eat {0} apples".format(number + 1)
# Out:
# 'I eat 4 apples'

# %%
# 2개 이상의 값 넣기
number = 10
day = "three"
# "I ate {0} apples. so I was sick for {1} days.".format(number, day)
# 이름으로 넣기
# "I ate {number} apples. so I was sick for {day} days.".format(number=10, day='three')
# # 인덱스와 이름을 혼용해서 넣기
"I ate {0} apples. so I was sick for {day} days.".format(10, day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 days.'

# %%
#
######################################
# 왼쪽 정렬/ 오른쪽 정렬
# "{0:<10}".format("hi")
# "{0:>10}".format("hi")
# # 가운데 정렬
# "{0:^10}".format("hi")
# # 공백 채우기
# "{0:!^10}".format("hi")
# "{0:!<10}".format("hi")
# 도전하기
"{0:<3}{1:>10}".format("hi",'hcit')
# Out:
# 'hi       hcit'

# %%
#########################################

# 소수점 표현하기
y = 3.42134234
# "{0:0.4f}".format(y)
# "{0:10.4f}".format(y)
# { 또는 } 문자 표현하기
"{{ and }}".format()
# Out:
# '{ and }'

# %% [markdown]
# ### f 문자열 포매팅

# %%
##########################
##### f 문자열 포매팅 #####
##### .format() 대체
##########################
print("문자열: f 문자열 포매팅")
name = "홍길동"
age = 30
# f"나의 이름은 {name}입니다. 나이는 {age}입니다."

# age = 30
f"나는 내년이면 {age+1}살이 된다."
# Out:
# 문자열: f 문자열 포매팅
# '나는 내년이면 31살이 된다.'

# %%
# 딕셔너리는 f 문자열 포매팅에서 다음과 같이 사용
d = {"name": "홍길동", "age": 30}
f'나의 이름은 {d["name"]}입니다. 나이는 {d["age"]}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %%
# 정렬
# f'{"hi":<10}'  # 왼쪽 정렬
# f'{"hi":>10}'  # 오른쪽 정렬
f'{"hi":^10}'  # 가운데 정렬
# Out:
# '    hi    '

# %%
# 공백 채우기
y = 3.42134234
# f"{y:0.4f}"  # 소수점 4자리까지만 표현
# f"{y:10.4f}"  # 소수점 4자리까지 표현하고 총 자리수를 10으로 맞춤
# { } 문자를 표시
f"{{ and }}"
# Out:
# '{ and }'

# %% [markdown]
# ### 문자열: 관련 내장 함수들

# %%
##############################################
print("문자열: 관련 내장 함수들")
# 문자 개수 세기(count)
a = "hobby"
a.count("b")
# Out:
# 문자열: 관련 내장 함수들
# 2

# %%
# 위치 알려주기1(find)
a = "Python is the best choice"
# a.find("b")
# a.find("k")  # what value?
# # 위치 알려주기2(index)
a = "Life is too short"
# a.index("t")
a.index("k")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-3a6b84120043> in <module>()
#       5 a = "Life is too short"
#       6 # a.index("t")
# ----> 7 a.index("k")
#
# ValueError: substring not found

# %%
# 문자열 삽입(join)
# ",".join("abcd")
",".join(["a", "b", "c", "d"])
# Out:
# 'a,b,c,d'

# %%
# 소문자를 대문자로 바꾸기(upper)
a = "hi"
a.upper()
# 대문자를 소문자로 바꾸기(lower)
a = "IoT"
a.lower()
# Out:
# 'iot'

# %%
# 왼쪽 공백 지우기(lstrip)
a = " hi "
# a.lstrip()
# 오른쪽 공백 지우기(rstrip)
# a.rstrip()
# 양쪽 공백 지우기(strip)
a.strip()
# Out:
# 'hi'

# %%
# 문자열 바꾸기(replace)
a = "Life is too short"
a.replace("Life", "Your leg")
# Out:
# 'Your leg is too short'

# %%
# 문자열 나누기(split) -> 리스트로 변환하여 반환
a = "Life is too short"
a.split()
# b = "a:b:c:d"
# b.split(":")
# Out:
# ['Life', 'is', 'too', 'short']

# %%
#### 도전하기 #####
# format 함수 또는 f 문자열 포매팅을 이용해서 '!!!python!!!' 문자열을 출력해보시오.
"{0:!^12}".format("python")
f'{"python":!^12}'
