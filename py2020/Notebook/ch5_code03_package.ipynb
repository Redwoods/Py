# %% [markdown]
# <a href="https://colab.research.google.com/github/Redwoods/Py/blob/master/py2020/Notebook/ch5_code03_package.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 패키지
# ```
# ./game/__init__.py
# ./game/sound/__init__.py
# ./game/sound/echo.py
# ./game/graphic/__init__.py
# ./game/graphic/render.py
# ```

# %% [markdown]
# ## 패키지 테스트
# ```
# # echo.py
# def echo_test():
#     print("echo")
# ```
#
# ```
# # render.py
# from ..sound.echo import echo_test
# def render_test():
#     print ("render")
#     echo_test()
# ```
#
# ```
# from game.graphic.render import render_test
# render_test()
# ```

# %%
from game.sound.echo import echo_test
echo_test()
# Out:
# echo

# %%
from game.graphic.render import render_test
 
render_test()
# Out:
# render
# echo
