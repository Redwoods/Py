# %% [markdown]
# <a href="https://colab.research.google.com/github/Redwoods/Py/blob/master/py2019/Lec/notebook/ch01_ex01_hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ch01_01_hello.ipynb

# %%
a=1
b=2
c=a+b
print(c)

# %% [markdown]
# #### 문자열 출력

# %%
###########
s1="Hello Python!"
print(s1)

# %% [markdown]
# #### list 선언과 출력

# %%
#################
x=[1,2,3]
y=[4,5,6]
print(x)
print(x,y)
x+y

# %% [markdown]
# ### 함수 정의와 실행

# %%
# function
def add(a,b):
    return a+b
#
print(add(1,2))
print(add(x,y))
