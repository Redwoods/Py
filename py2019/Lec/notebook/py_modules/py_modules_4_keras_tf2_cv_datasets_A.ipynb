# %% [markdown]
# <a href="https://colab.research.google.com/github/Redwoods/Lec/blob/master/simulation/code/py_modules/py_modules_4_keras_tf2_cv_datasets_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## CV (Computer vision) datasets in AI
# - from keras
#     - MNIST
#     - Fashion-MNIST
#     - CIFAR-10
#     - CIFAR-100

# %% [markdown]
# ### MNIST (Modified National Institute of Standards and Technology)
# - (60000, 28, 28), train
# - (10000, 28, 28), test
# - grayscale images of handwritten single digits between 0 and 9

# %%
# use TensorFlow 2.x 
# %tensorflow_version 2.x
# %tensorflow_version 1.x

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

print(tf.__version__)

# %%
from keras.datasets import mnist

# %%
# load dataset
(trainX, trainy), (testX, testy) = mnist.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# %%
# plot first few images
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
	# plot raw pixel data
	plt.imshow(trainX[i], cmap=plt.get_cmap('gray'))
# show the figure
# plt.show()

# %% [markdown]
# ### MNIST trainset

# %%
import numpy as np
type(trainy)
unique, counts = np.unique(trainy, return_counts=True)
mnist_train_dic = dict(zip(unique, counts))
mnist_train_dic

# %%
plt.bar(list(mnist_train_dic.keys()), mnist_train_dic.values(), color='g')

# %%
fig = plt.figure(figsize=(10,6))
for i in range(10):
    plt.subplot(2, 5, i+1)
    num0_9 = trainX[trainy == i]
    plt.imshow(num0_9[0], cmap='gray') #, interpolation='none')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### MNIST test set

# %%
# import numpy as np
type(testy)
unique, counts = np.unique(testy, return_counts=True)
mnist_test_dic = dict(zip(unique, counts))
mnist_test_dic

# %%
plt.bar(list(mnist_test_dic.keys()), mnist_test_dic.values(), color='g')

# %%
fig = plt.figure(figsize=(10,6))
for i in range(10):
    plt.subplot(2, 5, i+1)
    num0_9 = testX[testy == i]
    plt.imshow(num0_9[0], cmap='gray') #, interpolation='none')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### Fashion-MNIST Dataset
# - (60000, 28, 28), train
# - (10000, 28, 28), test
# - grayscale images of items of 10 types of clothing, such as shoes, t-shirts, dresses, and more.

# %%
from keras.datasets import fashion_mnist
# load dataset
(trainX, trainy), (testX, testy) = fashion_mnist.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# %%
# plot first few images
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
	# plot raw pixel data
	plt.imshow(trainX[i], cmap=plt.get_cmap('gray'))
# show the figure
# plt.show()

# %% [markdown]
# ### Fashion-MNIST trainset

# %%
import numpy as np
type(trainy)
unique, counts = np.unique(trainy, return_counts=True)
mnist_train_dic = dict(zip(unique, counts))
mnist_train_dic

# %%
plt.bar(list(mnist_train_dic.keys()), mnist_train_dic.values(), color='g')

# %%
fig = plt.figure(figsize=(10,6))
for i in range(10):
    plt.subplot(2, 5, i+1)
    num0_9 = trainX[trainy == i]
    plt.imshow(num0_9[0], cmap='gray') #, interpolation='none')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### Fashion-MNIST test set

# %%
# import numpy as np
type(testy)
unique, counts = np.unique(testy, return_counts=True)
mnist_test_dic = dict(zip(unique, counts))
mnist_test_dic

# %%
plt.bar(list(mnist_test_dic.keys()), mnist_test_dic.values(), color='g')

# %%
fig = plt.figure(figsize=(10,6))
for i in range(10):
    plt.subplot(2, 5, i+1)
    num0_9 = testX[testy == i]
    plt.imshow(num0_9[0], cmap='gray') #, interpolation='none')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### CIFAR-10 Dataset (CIFAR: Canadian Institute For Advanced Research)
# - (50000, 32, 32), train
# - (10000, 32, 32) test
# - color photographs of objects from 10 classes, such as frogs, birds, cats, ships, etc

# %%
from keras.datasets import cifar10
# load dataset
(trainX, trainy), (testX, testy) = cifar10.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# %%
# plot first few images
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
	# plot raw pixel data
	plt.imshow(trainX[i])
# show the figure
# plt.show()

# %% [markdown]
# ### CIFAR-10 trainset

# %%
# imp|ort numpy as np
type(trainy)
unique, counts = np.unique(trainy, return_counts=True)
mnist_train_dic = dict(zip(unique, counts))
mnist_train_dic

# %%
plt.bar(list(mnist_train_dic.keys()), mnist_train_dic.values(), color='g')

# %%
fig = plt.figure(figsize=(5,3))
for i in range(10):
    plt.subplot(2, 5, i+1)
    num0_9 = trainX[trainy[:,0] == i]
    plt.imshow(num0_9[0]) #, cmap='gray') #, interpolation='none')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### CIFAR-10 test set

# %%
# import numpy as np
type(testy)
unique, counts = np.unique(testy, return_counts=True)
mnist_test_dic = dict(zip(unique, counts))
mnist_test_dic

# %%
plt.bar(list(mnist_test_dic.keys()), mnist_test_dic.values(), color='g')

# %%
fig = plt.figure(figsize=(5,3))
for i in range(10):
    plt.subplot(2, 5, i+1)
    num0_9 = testX[testy[:,0] == i]
    plt.imshow(num0_9[0]) #, cmap='gray') #, interpolation='none')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### CIFAR-100 Dataset (CIFAR: Canadian Institute For Advanced Research)
# - (50000, 32, 32), train
# - (10000, 32, 32) test
# - color photographs of objects from 100 classes, such as fish, flowers, insects, and much more

# %%
from keras.datasets import cifar100
# load dataset
(trainX, trainy), (testX, testy) = cifar100.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# %%
# plot first few images
for i in range(9):
	# define subplot
	plt.subplot(330 + 1 + i)
	# plot raw pixel data
	plt.imshow(trainX[i])
# show the figure
# plt.show()

# %% [markdown]
# ### CIFAR-100 trainset

# %%
# import numpy as np
type(trainy)
unique, counts = np.unique(trainy, return_counts=True)
mnist_train_dic = dict(zip(unique, counts))
mnist_train_dic

# %%
plt.bar(list(mnist_train_dic.keys()), mnist_train_dic.values(), color='g')

# %%
fig = plt.figure(figsize=(10,13))
for i in range(100):
    plt.subplot(10, 10, i+1)
    num0_99 = trainX[trainy[:,0] == i]
    plt.imshow(num0_99[0])  #, cmap='gray') #, interpolation='none')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### CIFAR-100 test set

# %%
# import numpy as np
type(testy)
unique, counts = np.unique(testy, return_counts=True)
mnist_test_dic = dict(zip(unique, counts))
mnist_test_dic

# %%
plt.bar(list(mnist_test_dic.keys()), mnist_test_dic.values(), color='g')

# %%
fig = plt.figure(figsize=(10,13))
for i in range(100):
    plt.subplot(10, 10, i+1)
    num0_99 = testX[testy[:,0] == i]
    plt.imshow(num0_99[33]) #, cmap='gray') #, interpolation='none')
    plt.title("Class %d" % (i))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### class=0, 과일 그림 모음

# %%
fig = plt.figure(figsize=(10,13))
for i in range(100):
    plt.subplot(10, 10, i+1)
    num0_100 = testX[testy[:,0] == 0]
    plt.imshow(num0_100[i]) #, cmap='gray') #, interpolation='none')
    plt.title("Class %d" % (0))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ### class=35, 사람 사진 모음

# %%
fig = plt.figure(figsize=(10,13))
for i in range(100):
    plt.subplot(10, 10, i+1)
    num0_100 = testX[testy[:,0] == 35]
    plt.imshow(num0_100[i]) #, cmap='gray') #, interpolation='none')
    plt.title("Class %d" % (35))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ## What is your dataset?
